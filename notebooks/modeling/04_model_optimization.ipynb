# %% [markdown]
# ## Hyperparameter Tuning with Optuna
#
# **Goal:** Optimize LightGBM and XGBoost hyperparameters using Optuna for improved performance.
#
# **Base Features:** Phase 5 final features (95 features)

# %% [markdown]
# ### Setup & Imports

# %%
import pandas as pd
import numpy as np
import json
import os
import warnings
from typing import Dict

import optuna
from optuna.visualization import (
    plot_optimization_history,
    plot_param_importances,
    plot_parallel_coordinate
)

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import roc_auc_score, classification_report

import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

import joblib

np.random.seed(42)
warnings.filterwarnings('ignore')

print("Optuna version:", optuna.__version__)
print("LightGBM imported successfully")
print("XGBoost imported successfully")
# Out:
# Optuna version: 4.5.0
# LightGBM imported successfully
# XGBoost imported successfully

# %% [markdown]
# ### Load Phase 5 Final Features
#
# Load the best feature set from Phase 5 (95 features after all feature engineering phases).

# %%
X_train = pd.read_csv('../../data/processed/phase5_installments/X_train.csv')
y_train = pd.read_csv('../../data/processed/phase5_installments/y_train.csv')
X_val = pd.read_csv('../../data/processed/phase5_installments/X_val.csv')
y_val = pd.read_csv('../../data/processed/phase5_installments/y_val.csv')
X_test = pd.read_csv('../../data/processed/phase5_installments/X_test.csv')

with open('../../data/processed/phase5_installments/feature_metadata.json', 'r') as f:
    phase5_metadata = json.load(f)

X_train = X_train.drop('SK_ID_CURR', axis=1)
X_val = X_val.drop('SK_ID_CURR', axis=1)
test_ids = X_test['SK_ID_CURR'].copy()
X_test = X_test.drop('SK_ID_CURR', axis=1)

y_train = y_train['TARGET'].values
y_val = y_val['TARGET'].values

print(f"Train shape: {X_train.shape}")
print(f"Val shape: {X_val.shape}")
print(f"Test shape: {X_test.shape}")
print(f"\nPhase 5 Baseline Performance:")
print(f"  LightGBM CV AUC: {phase5_metadata['cv_eval']['lgb_cv_mean']:.4f}")
print(f"  XGBoost CV AUC: {phase5_metadata['cv_eval']['xgb_cv_mean']:.4f}")
# Out:
# Train shape: (246008, 95)
# Val shape: (61503, 95)
# Test shape: (48744, 95)
#
# Phase 5 Baseline Performance:
#   LightGBM CV AUC: 0.7755
#   XGBoost CV AUC: 0.7674

# %% [markdown]
# ### LightGBM Hyperparameter Tuning

# %%
def lgb_objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'class_weight': 'balanced',
        'random_state': 42,
        'verbose': -1
    }
    
    model = LGBMClassifier(**params)
    
    X_full = pd.concat([X_train, X_val], axis=0).reset_index(drop=True)
    y_full = np.concatenate([y_train, y_val])
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_full, y_full, cv=cv, scoring='roc_auc', n_jobs=-1)
    
    return scores.mean()

print("LightGBM objective function defined")
# Out:
# LightGBM objective function defined

# %%
# %%time

study_lgb = optuna.create_study(
    direction='maximize',
    study_name='lightgbm_tuning',
    sampler=optuna.samplers.TPESampler(seed=42),
    pruner=optuna.pruners.MedianPruner()
)

study_lgb.optimize(lgb_objective, n_trials=150, show_progress_bar=True, n_jobs=1)

print(f"\nBest trial:")
print(f"  Value (CV AUC): {study_lgb.best_trial.value:.4f}")
print(f"  Params: ")
for key, value in study_lgb.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-13 15:01:54,075] A new study created in memory with name: lightgbm_tuning
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2025-11-13 15:02:36,086] Trial 0 finished with value: 0.7235749168651157 and parameters: {'n_estimators': 437, 'learning_rate': 0.2536999076681772, 'max_depth': 10, 'num_leaves': 68, 'min_child_samples': 19, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598}. Best is trial 0 with value: 0.7235749168651157.
# [I 2025-11-13 15:04:26,405] Trial 1 finished with value: 0.7775540100480551 and parameters: {'n_estimators': 737, 'learning_rate': 0.010725209743171996, 'max_depth': 12, 'num_leaves': 87, 'min_child_samples': 25, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 1 with value: 0.7775540100480551.
# [I 2025-11-13 15:05:27,934] Trial 2 finished with value: 0.7767684702749509 and parameters: {'n_estimators': 489, 'learning_rate': 0.02692655251486473, 'max_depth': 9, 'num_leaves': 31, 'min_child_samples': 33, 'subsample': 0.6831809216468459, 'colsample_bytree': 0.728034992108518, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 6.267062696005991e-07}. Best is trial 1 with value: 0.7775540100480551.
# [I 2025-11-13 15:06:05,958] Trial 3 finished with value: 0.777674216976284 and parameters: {'n_estimators': 563, 'learning_rate': 0.07500118950416987, 'max_depth': 3, 'num_leaves': 69, 'min_child_samples': 21, 'subsample': 0.5325257964926398, 'colsample_bytree': 0.9744427686266666, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:07:01,711] Trial 4 finished with value: 0.7727264486403954 and parameters: {'n_estimators': 374, 'learning_rate': 0.013940346079873234, 'max_depth': 9, 'num_leaves': 55, 'min_child_samples': 16, 'subsample': 0.7475884550556351, 'colsample_bytree': 0.5171942605576092, 'reg_alpha': 1.527156759251193, 'reg_lambda': 2.133142332373004e-06}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:09:02,649] Trial 5 finished with value: 0.7764428387915269 and parameters: {'n_estimators': 696, 'learning_rate': 0.028869220380495747, 'max_depth': 8, 'num_leaves': 64, 'min_child_samples': 22, 'subsample': 0.9847923138822793, 'colsample_bytree': 0.8875664116805573, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:09:49,503] Trial 6 finished with value: 0.7717879927559992 and parameters: {'n_estimators': 638, 'learning_rate': 0.22999586428143728, 'max_depth': 3, 'num_leaves': 35, 'min_child_samples': 9, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 0.28749982347407854}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:10:53,050] Trial 7 finished with value: 0.776520459806575 and parameters: {'n_estimators': 421, 'learning_rate': 0.026000059117302653, 'max_depth': 8, 'num_leaves': 31, 'min_child_samples': 82, 'subsample': 0.5372753218398854, 'colsample_bytree': 0.9934434683002586, 'reg_alpha': 0.08916674715636537, 'reg_lambda': 6.143857495033091e-07}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:11:13,253] Trial 8 finished with value: 0.7695503646395732 and parameters: {'n_estimators': 104, 'learning_rate': 0.1601531217136121, 'max_depth': 10, 'num_leaves': 79, 'min_child_samples': 79, 'subsample': 0.5370223258670452, 'colsample_bytree': 0.6792328642721364, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 0.5860448217200517}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:11:52,871] Trial 9 finished with value: 0.7733279657829644 and parameters: {'n_estimators': 661, 'learning_rate': 0.030816017044468066, 'max_depth': 3, 'num_leaves': 45, 'min_child_samples': 36, 'subsample': 0.864803089169032, 'colsample_bytree': 0.8187787356776066, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.0001778010520878397}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:13:20,955] Trial 10 finished with value: 0.7665119190930941 and parameters: {'n_estimators': 951, 'learning_rate': 0.09121222976475846, 'max_depth': 5, 'num_leaves': 95, 'min_child_samples': 59, 'subsample': 0.8451235367845726, 'colsample_bytree': 0.9865417857436737, 'reg_alpha': 0.0025074987853267337, 'reg_lambda': 0.008349484536843164}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:15:30,481] Trial 11 finished with value: 0.7565866372310943 and parameters: {'n_estimators': 914, 'learning_rate': 0.06729620898601191, 'max_depth': 12, 'num_leaves': 88, 'min_child_samples': 48, 'subsample': 0.6216895113171046, 'colsample_bytree': 0.6136901193066356, 'reg_alpha': 6.982496886163948e-05, 'reg_lambda': 0.00014727255511652628}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:17:25,169] Trial 12 finished with value: 0.7750810669944773 and parameters: {'n_estimators': 815, 'learning_rate': 0.012903803553405412, 'max_depth': 6, 'num_leaves': 75, 'min_child_samples': 53, 'subsample': 0.5244164304085682, 'colsample_bytree': 0.8468909147231947, 'reg_alpha': 0.0001855855438816641, 'reg_lambda': 0.029175077260790813}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:18:14,714] Trial 13 finished with value: 0.772955556703325 and parameters: {'n_estimators': 259, 'learning_rate': 0.09154387249271213, 'max_depth': 12, 'num_leaves': 100, 'min_child_samples': 5, 'subsample': 0.6123366282341044, 'colsample_bytree': 0.62077746649017, 'reg_alpha': 5.106427590988349e-08, 'reg_lambda': 9.554024515443208}. Best is trial 3 with value: 0.777674216976284.
# [I 2025-11-13 15:19:02,920] Trial 14 finished with value: 0.7776885780264464 and parameters: {'n_estimators': 757, 'learning_rate': 0.04644344157387815, 'max_depth': 4, 'num_leaves': 84, 'min_child_samples': 34, 'subsample': 0.730666690330899, 'colsample_bytree': 0.7841476612479287, 'reg_alpha': 4.448098583586063e-06, 'reg_lambda': 1.0604434612489142e-05}. Best is trial 14 with value: 0.7776885780264464.
# [I 2025-11-13 15:20:13,256] Trial 15 finished with value: 0.7761807557042513 and parameters: {'n_estimators': 586, 'learning_rate': 0.04962462697008441, 'max_depth': 5, 'num_leaves': 53, 'min_child_samples': 42, 'subsample': 0.7803443096633093, 'colsample_bytree': 0.9197573760996658, 'reg_alpha': 0.003043263840972833, 'reg_lambda': 1.0170113648329553e-05}. Best is trial 14 with value: 0.7776885780264464.
# [I 2025-11-13 15:21:16,641] Trial 16 finished with value: 0.7777960645713593 and parameters: {'n_estimators': 837, 'learning_rate': 0.04906506214258567, 'max_depth': 4, 'num_leaves': 74, 'min_child_samples': 65, 'subsample': 0.9734024632067816, 'colsample_bytree': 0.7949298629353718, 'reg_alpha': 1.6223240044222361e-06, 'reg_lambda': 1.314053143275926e-08}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:22:35,430] Trial 17 finished with value: 0.7763175153916018 and parameters: {'n_estimators': 825, 'learning_rate': 0.044207413119892784, 'max_depth': 5, 'num_leaves': 80, 'min_child_samples': 65, 'subsample': 0.9991574382398791, 'colsample_bytree': 0.780746092932732, 'reg_alpha': 1.250036930766165e-06, 'reg_lambda': 1.5859574916758566e-08}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:24:12,437] Trial 18 finished with value: 0.7446613514921051 and parameters: {'n_estimators': 999, 'learning_rate': 0.14982807062764933, 'max_depth': 6, 'num_leaves': 91, 'min_child_samples': 70, 'subsample': 0.925680289293533, 'colsample_bytree': 0.7686346138813421, 'reg_alpha': 3.0809723391197865e-07, 'reg_lambda': 1.436705249050901e-08}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:25:14,436] Trial 19 finished with value: 0.777767944276562 and parameters: {'n_estimators': 824, 'learning_rate': 0.03856103089610464, 'max_depth': 4, 'num_leaves': 74, 'min_child_samples': 96, 'subsample': 0.7530424861681704, 'colsample_bytree': 0.8163151963811591, 'reg_alpha': 2.984922009781727e-05, 'reg_lambda': 1.6921462119151743e-07}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:27:47,810] Trial 20 finished with value: 0.7766468685534035 and parameters: {'n_estimators': 870, 'learning_rate': 0.018258538801837254, 'max_depth': 7, 'num_leaves': 72, 'min_child_samples': 100, 'subsample': 0.8199212859905153, 'colsample_bytree': 0.8663678687988137, 'reg_alpha': 1.2722974438529106e-08, 'reg_lambda': 8.03854677747684e-08}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:29:11,112] Trial 21 finished with value: 0.777504742598153 and parameters: {'n_estimators': 763, 'learning_rate': 0.04104972780565057, 'max_depth': 4, 'num_leaves': 83, 'min_child_samples': 98, 'subsample': 0.7463733043320269, 'colsample_bytree': 0.8055752528688316, 'reg_alpha': 2.3685862319132032e-05, 'reg_lambda': 1.4380556845034231e-05}. Best is trial 16 with value: 0.7777960645713593.
# [I 2025-11-13 15:30:32,993] Trial 22 finished with value: 0.7778370223464449 and parameters: {'n_estimators': 819, 'learning_rate': 0.03761739905584087, 'max_depth': 4, 'num_leaves': 60, 'min_child_samples': 89, 'subsample': 0.696194111977565, 'colsample_bytree': 0.7327122497128112, 'reg_alpha': 0.0014334503648906704, 'reg_lambda': 1.3029941751007683e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:31:40,975] Trial 23 finished with value: 0.7750873168385557 and parameters: {'n_estimators': 861, 'learning_rate': 0.019572017766656107, 'max_depth': 4, 'num_leaves': 58, 'min_child_samples': 89, 'subsample': 0.6957180283517158, 'colsample_bytree': 0.7257341309694799, 'reg_alpha': 0.002892549511293959, 'reg_lambda': 1.0209699332115788e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:33:26,794] Trial 24 finished with value: 0.7752442510658304 and parameters: {'n_estimators': 981, 'learning_rate': 0.03632922861461887, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 89, 'subsample': 0.8002978262698033, 'colsample_bytree': 0.6721148329848075, 'reg_alpha': 0.0006909014520498358, 'reg_lambda': 8.967045395671401e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:34:37,913] Trial 25 finished with value: 0.7770129579782278 and parameters: {'n_estimators': 906, 'learning_rate': 0.061669330791715625, 'max_depth': 4, 'num_leaves': 62, 'min_child_samples': 74, 'subsample': 0.9145942595193252, 'colsample_bytree': 0.9059296409157412, 'reg_alpha': 3.89316131659374e-05, 'reg_lambda': 1.0483101255897313e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:35:51,713] Trial 26 finished with value: 0.7762246383659385 and parameters: {'n_estimators': 802, 'learning_rate': 0.020531362707168422, 'max_depth': 5, 'num_leaves': 46, 'min_child_samples': 90, 'subsample': 0.8878041514145321, 'colsample_bytree': 0.8332201169869748, 'reg_alpha': 0.0005885435697411537, 'reg_lambda': 5.660217463286176e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:36:54,773] Trial 27 finished with value: 0.7778123138152082 and parameters: {'n_estimators': 696, 'learning_rate': 0.1022268832486803, 'max_depth': 3, 'num_leaves': 75, 'min_child_samples': 82, 'subsample': 0.959074633599213, 'colsample_bytree': 0.7403748782555238, 'reg_alpha': 6.865560220049295e-07, 'reg_lambda': 7.645098547254033e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:37:33,798] Trial 28 finished with value: 0.776360068147959 and parameters: {'n_estimators': 676, 'learning_rate': 0.1391080276509161, 'max_depth': 3, 'num_leaves': 64, 'min_child_samples': 65, 'subsample': 0.9304540972835353, 'colsample_bytree': 0.7414892122778909, 'reg_alpha': 5.57279661938736e-07, 'reg_lambda': 4.601769561330307e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:38:23,740] Trial 29 finished with value: 0.7690213820834156 and parameters: {'n_estimators': 506, 'learning_rate': 0.09801507493229912, 'max_depth': 7, 'num_leaves': 41, 'min_child_samples': 80, 'subsample': 0.9614446966831018, 'colsample_bytree': 0.6957905220003778, 'reg_alpha': 0.062352924376888545, 'reg_lambda': 5.1885312114387865e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:39:05,774] Trial 30 finished with value: 0.777403296441556 and parameters: {'n_estimators': 608, 'learning_rate': 0.11461769400683587, 'max_depth': 3, 'num_leaves': 68, 'min_child_samples': 71, 'subsample': 0.9444029539665947, 'colsample_bytree': 0.5615546708760338, 'reg_alpha': 2.036717484521091e-08, 'reg_lambda': 4.552986202129344e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:39:56,160] Trial 31 finished with value: 0.7776850825073173 and parameters: {'n_estimators': 722, 'learning_rate': 0.0573260568294676, 'max_depth': 4, 'num_leaves': 75, 'min_child_samples': 94, 'subsample': 0.8911919725830543, 'colsample_bytree': 0.6489968289300371, 'reg_alpha': 1.2417016938961964e-05, 'reg_lambda': 2.4051980343762424e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:41:07,139] Trial 32 finished with value: 0.7773282883432048 and parameters: {'n_estimators': 777, 'learning_rate': 0.035016120430970556, 'max_depth': 4, 'num_leaves': 68, 'min_child_samples': 86, 'subsample': 0.7109138559626985, 'colsample_bytree': 0.7481229185107232, 'reg_alpha': 0.01501981961556658, 'reg_lambda': 4.1959557372360674e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:42:21,581] Trial 33 finished with value: 0.7719680480601155 and parameters: {'n_estimators': 882, 'learning_rate': 0.07658076434823764, 'max_depth': 5, 'num_leaves': 59, 'min_child_samples': 77, 'subsample': 0.65175218995759, 'colsample_bytree': 0.7946399042170768, 'reg_alpha': 0.00015120934820217244, 'reg_lambda': 2.0922359521421207e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:43:12,764] Trial 34 finished with value: 0.7676302261123469 and parameters: {'n_estimators': 716, 'learning_rate': 0.2931797530356798, 'max_depth': 3, 'num_leaves': 76, 'min_child_samples': 96, 'subsample': 0.775197078607596, 'colsample_bytree': 0.7202623914369682, 'reg_alpha': 1.0289690065477595e-05, 'reg_lambda': 2.6541909611749676e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:44:40,663] Trial 35 finished with value: 0.7722536309566779 and parameters: {'n_estimators': 835, 'learning_rate': 0.053039671273608514, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 84, 'subsample': 0.5691986641997921, 'colsample_bytree': 0.8575893223992019, 'reg_alpha': 1.7023175758299137e-06, 'reg_lambda': 1.6016658804102676e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:45:58,879] Trial 36 finished with value: 0.7766964482637604 and parameters: {'n_estimators': 949, 'learning_rate': 0.024975037382827664, 'max_depth': 4, 'num_leaves': 66, 'min_child_samples': 64, 'subsample': 0.9659835474027306, 'colsample_bytree': 0.9268381767504691, 'reg_alpha': 2.4603068752033455e-07, 'reg_lambda': 3.5246775073889115e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:46:30,913] Trial 37 finished with value: 0.7730310591224774 and parameters: {'n_estimators': 516, 'learning_rate': 0.03786567769154138, 'max_depth': 3, 'num_leaves': 79, 'min_child_samples': 95, 'subsample': 0.8368545208990883, 'colsample_bytree': 0.7657373416129553, 'reg_alpha': 6.947307091487079e-07, 'reg_lambda': 0.0015837672407951334}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:47:21,150] Trial 38 finished with value: 0.7753586652705995 and parameters: {'n_estimators': 634, 'learning_rate': 0.07429831690116942, 'max_depth': 5, 'num_leaves': 23, 'min_child_samples': 56, 'subsample': 0.6626014323367526, 'colsample_bytree': 0.8129227331827118, 'reg_alpha': 5.317950940762494e-06, 'reg_lambda': 1.9587958575539685e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:48:06,586] Trial 39 finished with value: 0.7729160447250528 and parameters: {'n_estimators': 746, 'learning_rate': 0.20584037287704138, 'max_depth': 3, 'num_leaves': 73, 'min_child_samples': 75, 'subsample': 0.8970120599183788, 'colsample_bytree': 0.883323841629601, 'reg_alpha': 0.017800963972689487, 'reg_lambda': 9.187118727887034e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:50:07,360] Trial 40 finished with value: 0.7769085551563545 and parameters: {'n_estimators': 699, 'learning_rate': 0.02380945523214707, 'max_depth': 9, 'num_leaves': 56, 'min_child_samples': 92, 'subsample': 0.9770215434469051, 'colsample_bytree': 0.9485551860338081, 'reg_alpha': 7.497779697762797e-05, 'reg_lambda': 3.2750340953417674e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:51:20,839] Trial 41 finished with value: 0.7776951779091752 and parameters: {'n_estimators': 791, 'learning_rate': 0.04703720054643072, 'max_depth': 4, 'num_leaves': 84, 'min_child_samples': 28, 'subsample': 0.7161595359788985, 'colsample_bytree': 0.7787350608319898, 'reg_alpha': 4.45349033608854e-06, 'reg_lambda': 2.4430458060920264e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:52:13,831] Trial 42 finished with value: 0.7767831439126642 and parameters: {'n_estimators': 809, 'learning_rate': 0.032386399604175144, 'max_depth': 4, 'num_leaves': 89, 'min_child_samples': 17, 'subsample': 0.7077076127134286, 'colsample_bytree': 0.7066738512538215, 'reg_alpha': 1.304033128935655e-07, 'reg_lambda': 0.0008299591273903602}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:53:09,190] Trial 43 finished with value: 0.7774612763373309 and parameters: {'n_estimators': 909, 'learning_rate': 0.05297332831676526, 'max_depth': 3, 'num_leaves': 85, 'min_child_samples': 28, 'subsample': 0.6388517406791329, 'colsample_bytree': 0.7604789976571527, 'reg_alpha': 1.5437773804000007e-05, 'reg_lambda': 4.562459414742849e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:54:23,665] Trial 44 finished with value: 0.7724720888370812 and parameters: {'n_estimators': 853, 'learning_rate': 0.06763788962274891, 'max_depth': 5, 'num_leaves': 81, 'min_child_samples': 45, 'subsample': 0.6756283319027342, 'colsample_bytree': 0.8179146896207607, 'reg_alpha': 2.097615956217143e-06, 'reg_lambda': 2.1061286667544546e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:56:24,470] Trial 45 finished with value: 0.7757278162378579 and parameters: {'n_estimators': 781, 'learning_rate': 0.028672623610780462, 'max_depth': 11, 'num_leaves': 77, 'min_child_samples': 84, 'subsample': 0.5785305452661514, 'colsample_bytree': 0.6611178843032743, 'reg_alpha': 0.0008325526904505292, 'reg_lambda': 4.202562939655703e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:57:11,010] Trial 46 finished with value: 0.7771965878871901 and parameters: {'n_estimators': 660, 'learning_rate': 0.041833498262016586, 'max_depth': 4, 'num_leaves': 91, 'min_child_samples': 60, 'subsample': 0.7271351998478127, 'colsample_bytree': 0.7390078941008074, 'reg_alpha': 6.016871250643068e-08, 'reg_lambda': 8.156156228880284e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:57:32,311] Trial 47 finished with value: 0.7751867725544226 and parameters: {'n_estimators': 335, 'learning_rate': 0.08237339932265902, 'max_depth': 3, 'num_leaves': 96, 'min_child_samples': 12, 'subsample': 0.7614228656018701, 'colsample_bytree': 0.8353967080832627, 'reg_alpha': 0.3335241926254416, 'reg_lambda': 1.1727045233124423e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:58:26,357] Trial 48 finished with value: 0.769532348117828 and parameters: {'n_estimators': 554, 'learning_rate': 0.1135781543052314, 'max_depth': 5, 'num_leaves': 71, 'min_child_samples': 39, 'subsample': 0.8738187980504838, 'colsample_bytree': 0.787536910338129, 'reg_alpha': 4.152455986357169e-06, 'reg_lambda': 2.895652880903327e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 15:59:44,381] Trial 49 finished with value: 0.7704635483494069 and parameters: {'n_estimators': 726, 'learning_rate': 0.060088001353390534, 'max_depth': 6, 'num_leaves': 66, 'min_child_samples': 50, 'subsample': 0.6154432499594399, 'colsample_bytree': 0.7142315472517111, 'reg_alpha': 5.275946633027559e-05, 'reg_lambda': 0.00534504177275285}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:00:22,709] Trial 50 finished with value: 0.7758619221792463 and parameters: {'n_estimators': 450, 'learning_rate': 0.045491524858135304, 'max_depth': 4, 'num_leaves': 62, 'min_child_samples': 69, 'subsample': 0.8063067651702059, 'colsample_bytree': 0.6919578886295747, 'reg_alpha': 0.0002516169469614901, 'reg_lambda': 0.03492306849406344}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:01:28,592] Trial 51 finished with value: 0.7775071848100147 and parameters: {'n_estimators': 760, 'learning_rate': 0.0464269185374874, 'max_depth': 4, 'num_leaves': 84, 'min_child_samples': 31, 'subsample': 0.7305708804181046, 'colsample_bytree': 0.7732681151643118, 'reg_alpha': 6.217236290727853e-06, 'reg_lambda': 4.0160824511322554e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:02:34,960] Trial 52 finished with value: 0.7772913372101581 and parameters: {'n_estimators': 943, 'learning_rate': 0.03143565507575321, 'max_depth': 4, 'num_leaves': 95, 'min_child_samples': 23, 'subsample': 0.6888835331044042, 'colsample_bytree': 0.7957371866287697, 'reg_alpha': 7.908557689557948e-07, 'reg_lambda': 1.5520966262651645e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:03:35,889] Trial 53 finished with value: 0.7759859708927745 and parameters: {'n_estimators': 801, 'learning_rate': 0.03879333581305178, 'max_depth': 3, 'num_leaves': 82, 'min_child_samples': 34, 'subsample': 0.7406909320047569, 'colsample_bytree': 0.7514706783687627, 'reg_alpha': 2.8160155342044213e-06, 'reg_lambda': 0.00014902675575369136}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:04:59,025] Trial 54 finished with value: 0.7740385573480653 and parameters: {'n_estimators': 872, 'learning_rate': 0.05156170099960639, 'max_depth': 5, 'num_leaves': 88, 'min_child_samples': 26, 'subsample': 0.7712412714867276, 'colsample_bytree': 0.8281925136274259, 'reg_alpha': 2.812349326167123e-07, 'reg_lambda': 0.0002772120510357615}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:05:34,330] Trial 55 finished with value: 0.7777127946288948 and parameters: {'n_estimators': 752, 'learning_rate': 0.06632384960853989, 'max_depth': 3, 'num_leaves': 78, 'min_child_samples': 86, 'subsample': 0.5028549522647843, 'colsample_bytree': 0.781930302116874, 'reg_alpha': 2.7383583589082782e-05, 'reg_lambda': 5.1637790830207015e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:05:50,200] Trial 56 finished with value: 0.7683350758883487 and parameters: {'n_estimators': 184, 'learning_rate': 0.0669913372708798, 'max_depth': 3, 'num_leaves': 74, 'min_child_samples': 86, 'subsample': 0.8509539232402732, 'colsample_bytree': 0.8487758440841627, 'reg_alpha': 0.001466189234176712, 'reg_lambda': 5.502938513465371e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:06:53,773] Trial 57 finished with value: 0.7737672595050129 and parameters: {'n_estimators': 825, 'learning_rate': 0.10940292885350014, 'max_depth': 4, 'num_leaves': 77, 'min_child_samples': 100, 'subsample': 0.5070587568226921, 'colsample_bytree': 0.8777875812133029, 'reg_alpha': 2.5990196029350962e-05, 'reg_lambda': 6.654930470699952e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:07:24,794] Trial 58 finished with value: 0.777600872757245 and parameters: {'n_estimators': 679, 'learning_rate': 0.08214549737287212, 'max_depth': 3, 'num_leaves': 79, 'min_child_samples': 80, 'subsample': 0.5537158657742864, 'colsample_bytree': 0.7306424413503869, 'reg_alpha': 0.00011112572668449394, 'reg_lambda': 3.993809333101485e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:09:01,639] Trial 59 finished with value: 0.7745381387500171 and parameters: {'n_estimators': 606, 'learning_rate': 0.010424389596549124, 'max_depth': 8, 'num_leaves': 53, 'min_child_samples': 91, 'subsample': 0.5974017128445887, 'colsample_bytree': 0.8006702717842978, 'reg_alpha': 2.7758594897628362e-05, 'reg_lambda': 1.3054664728715695e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:09:57,043] Trial 60 finished with value: 0.7634135298862702 and parameters: {'n_estimators': 896, 'learning_rate': 0.1283912303041396, 'max_depth': 5, 'num_leaves': 61, 'min_child_samples': 87, 'subsample': 0.9499843471465985, 'colsample_bytree': 0.776628182554089, 'reg_alpha': 0.0003438979429883044, 'reg_lambda': 1.567849591439389e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:10:51,867] Trial 61 finished with value: 0.7767093531553879 and parameters: {'n_estimators': 781, 'learning_rate': 0.033242413755806, 'max_depth': 4, 'num_leaves': 86, 'min_child_samples': 38, 'subsample': 0.7146040198917978, 'colsample_bytree': 0.7578453146017488, 'reg_alpha': 7.081106078024342e-06, 'reg_lambda': 2.635967326712221e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:11:30,459] Trial 62 finished with value: 0.77704492075157 and parameters: {'n_estimators': 844, 'learning_rate': 0.04738807060971907, 'max_depth': 3, 'num_leaves': 92, 'min_child_samples': 19, 'subsample': 0.7930347715338235, 'colsample_bytree': 0.7818579203035801, 'reg_alpha': 1.0302523261294626e-06, 'reg_lambda': 8.935100124294006e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:12:13,173] Trial 63 finished with value: 0.7777504976848114 and parameters: {'n_estimators': 738, 'learning_rate': 0.04225440088005604, 'max_depth': 4, 'num_leaves': 72, 'min_child_samples': 93, 'subsample': 0.9936725502311813, 'colsample_bytree': 0.8074003493102679, 'reg_alpha': 0.006583640527327037, 'reg_lambda': 6.312629841229384e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:12:50,152] Trial 64 finished with value: 0.7666665096816179 and parameters: {'n_estimators': 736, 'learning_rate': 0.17948918859412752, 'max_depth': 4, 'num_leaves': 72, 'min_child_samples': 93, 'subsample': 0.9964048455367367, 'colsample_bytree': 0.8318292817572507, 'reg_alpha': 0.006264320573165127, 'reg_lambda': 3.0562906181518327e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:13:24,790] Trial 65 finished with value: 0.7754949255031673 and parameters: {'n_estimators': 701, 'learning_rate': 0.04102318789439716, 'max_depth': 3, 'num_leaves': 70, 'min_child_samples': 82, 'subsample': 0.9888870231748105, 'colsample_bytree': 0.8138577027273673, 'reg_alpha': 0.008172328353217724, 'reg_lambda': 7.174569833087558e-06}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:14:09,410] Trial 66 finished with value: 0.7765063685846354 and parameters: {'n_estimators': 799, 'learning_rate': 0.027449598635944376, 'max_depth': 4, 'num_leaves': 67, 'min_child_samples': 97, 'subsample': 0.9153662461073653, 'colsample_bytree': 0.737390334495988, 'reg_alpha': 0.022049657672121224, 'reg_lambda': 6.344565768072786e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:15:00,494] Trial 67 finished with value: 0.7746227532507597 and parameters: {'n_estimators': 756, 'learning_rate': 0.06262082837325135, 'max_depth': 5, 'num_leaves': 78, 'min_child_samples': 78, 'subsample': 0.9729136821427447, 'colsample_bytree': 0.869153110026156, 'reg_alpha': 0.0015126480140822893, 'reg_lambda': 1.256524529857136e-08}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:15:42,991] Trial 68 finished with value: 0.7764192392466251 and parameters: {'n_estimators': 931, 'learning_rate': 0.03637508852412532, 'max_depth': 3, 'num_leaves': 64, 'min_child_samples': 88, 'subsample': 0.9376545776867776, 'colsample_bytree': 0.8042813298886438, 'reg_alpha': 1.4070934378581604e-05, 'reg_lambda': 5.543432477499782e-07}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:16:28,370] Trial 69 finished with value: 0.7776268807017451 and parameters: {'n_estimators': 656, 'learning_rate': 0.05554002262616291, 'max_depth': 4, 'num_leaves': 82, 'min_child_samples': 73, 'subsample': 0.9547974290374994, 'colsample_bytree': 0.8449089351808959, 'reg_alpha': 4.33282131302047e-07, 'reg_lambda': 1.7593159333186292e-05}. Best is trial 22 with value: 0.7778370223464449.
# [I 2025-11-13 16:17:06,075] Trial 70 finished with value: 0.7778842850047123 and parameters: {'n_estimators': 855, 'learning_rate': 0.09328101611116905, 'max_depth': 3, 'num_leaves': 74, 'min_child_samples': 100, 'subsample': 0.631852170006414, 'colsample_bytree': 0.902690783412694, 'reg_alpha': 9.101949832447815e-05, 'reg_lambda': 2.0744483692863136e-08}. Best is trial 70 with value: 0.7778842850047123.
# [I 2025-11-13 16:17:47,062] Trial 71 finished with value: 0.7778673410612911 and parameters: {'n_estimators': 841, 'learning_rate': 0.09811067561253908, 'max_depth': 3, 'num_leaves': 74, 'min_child_samples': 100, 'subsample': 0.5009337746363238, 'colsample_bytree': 0.8993620912012912, 'reg_alpha': 7.892429947658599e-05, 'reg_lambda': 2.515735405452603e-08}. Best is trial 70 with value: 0.7778842850047123.
# [I 2025-11-13 16:18:23,152] Trial 72 finished with value: 0.7776920741414457 and parameters: {'n_estimators': 836, 'learning_rate': 0.10037180624148576, 'max_depth': 3, 'num_leaves': 75, 'min_child_samples': 100, 'subsample': 0.5426829403437774, 'colsample_bytree': 0.8987732684571585, 'reg_alpha': 9.881370792199673e-05, 'reg_lambda': 1.8164931730072327e-08}. Best is trial 70 with value: 0.7778842850047123.
# [I 2025-11-13 16:19:02,268] Trial 73 finished with value: 0.77608218747877 and parameters: {'n_estimators': 876, 'learning_rate': 0.1346235282112902, 'max_depth': 3, 'num_leaves': 72, 'min_child_samples': 96, 'subsample': 0.5067450338310191, 'colsample_bytree': 0.8603376976935455, 'reg_alpha': 0.00046575101667637223, 'reg_lambda': 3.116369458796169e-08}. Best is trial 70 with value: 0.7778842850047123.
# [I 2025-11-13 16:19:44,458] Trial 74 finished with value: 0.7780299106284778 and parameters: {'n_estimators': 830, 'learning_rate': 0.08939896978836512, 'max_depth': 3, 'num_leaves': 69, 'min_child_samples': 93, 'subsample': 0.5197732280786164, 'colsample_bytree': 0.9744296026818633, 'reg_alpha': 0.00019585537390949529, 'reg_lambda': 1.4227007764968687e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:20:31,191] Trial 75 finished with value: 0.7778290645320537 and parameters: {'n_estimators': 963, 'learning_rate': 0.09322372602703796, 'max_depth': 3, 'num_leaves': 69, 'min_child_samples': 92, 'subsample': 0.5328317500512643, 'colsample_bytree': 0.9527632067042173, 'reg_alpha': 0.00019295264389668532, 'reg_lambda': 1.3826070127624293e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:21:20,037] Trial 76 finished with value: 0.7774984047420607 and parameters: {'n_estimators': 963, 'learning_rate': 0.0892388800957604, 'max_depth': 3, 'num_leaves': 65, 'min_child_samples': 97, 'subsample': 0.5593682802869929, 'colsample_bytree': 0.9685939178970489, 'reg_alpha': 0.00022171500848573538, 'reg_lambda': 1.0292478568962833e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:22:08,358] Trial 77 finished with value: 0.7770734037844498 and parameters: {'n_estimators': 998, 'learning_rate': 0.10234653384581259, 'max_depth': 3, 'num_leaves': 68, 'min_child_samples': 90, 'subsample': 0.5277409757669025, 'colsample_bytree': 0.9537693720587612, 'reg_alpha': 0.00013320439158351094, 'reg_lambda': 1.6146972507444788e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:23:05,663] Trial 78 finished with value: 0.7775103263000626 and parameters: {'n_estimators': 968, 'learning_rate': 0.08868661530587905, 'max_depth': 3, 'num_leaves': 59, 'min_child_samples': 94, 'subsample': 0.5913874664966067, 'colsample_bytree': 0.9991373172227, 'reg_alpha': 5.307956083244954e-05, 'reg_lambda': 5.261260647379429e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:23:43,890] Trial 79 finished with value: 0.7744808783303453 and parameters: {'n_estimators': 889, 'learning_rate': 0.1592831679288345, 'max_depth': 3, 'num_leaves': 69, 'min_child_samples': 98, 'subsample': 0.6340377968810631, 'colsample_bytree': 0.9395450138290132, 'reg_alpha': 0.0009148748444875107, 'reg_lambda': 2.287708914377928e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:25:17,448] Trial 80 finished with value: 0.7433912569886048 and parameters: {'n_estimators': 918, 'learning_rate': 0.12341194060446271, 'max_depth': 10, 'num_leaves': 74, 'min_child_samples': 91, 'subsample': 0.523107890432688, 'colsample_bytree': 0.9052343511256319, 'reg_alpha': 0.0014682294782996572, 'reg_lambda': 1.1197266895845666e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:26:12,065] Trial 81 finished with value: 0.7778214895525062 and parameters: {'n_estimators': 858, 'learning_rate': 0.07472789752924631, 'max_depth': 4, 'num_leaves': 70, 'min_child_samples': 93, 'subsample': 0.5441334309445948, 'colsample_bytree': 0.9837358767400989, 'reg_alpha': 8.45933063172784, 'reg_lambda': 3.390566824400754e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:27:04,018] Trial 82 finished with value: 0.7771444576460087 and parameters: {'n_estimators': 861, 'learning_rate': 0.08131844273591586, 'max_depth': 4, 'num_leaves': 70, 'min_child_samples': 82, 'subsample': 0.5167693901712714, 'colsample_bytree': 0.9621367464642723, 'reg_alpha': 6.745553778210194, 'reg_lambda': 3.2021609129598105e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:27:55,099] Trial 83 finished with value: 0.77710942529047 and parameters: {'n_estimators': 820, 'learning_rate': 0.07202145753530698, 'max_depth': 4, 'num_leaves': 64, 'min_child_samples': 100, 'subsample': 0.5488123037283333, 'colsample_bytree': 0.9842367684984116, 'reg_alpha': 1.1264614588947894, 'reg_lambda': 9.030336095694874e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:28:36,618] Trial 84 finished with value: 0.7775281587227695 and parameters: {'n_estimators': 922, 'learning_rate': 0.09533888751244536, 'max_depth': 3, 'num_leaves': 76, 'min_child_samples': 94, 'subsample': 0.5754756721565355, 'colsample_bytree': 0.9249489529022228, 'reg_alpha': 0.20905131886245007, 'reg_lambda': 4.0747818961256786e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:29:25,383] Trial 85 finished with value: 0.7769728355920638 and parameters: {'n_estimators': 846, 'learning_rate': 0.12086886927696919, 'max_depth': 3, 'num_leaves': 57, 'min_child_samples': 89, 'subsample': 0.5647309103193502, 'colsample_bytree': 0.976151445562505, 'reg_alpha': 0.0003777457472013062, 'reg_lambda': 1.5765468890444862e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:30:16,917] Trial 86 finished with value: 0.7731755982841305 and parameters: {'n_estimators': 884, 'learning_rate': 0.10515256148541208, 'max_depth': 4, 'num_leaves': 54, 'min_child_samples': 95, 'subsample': 0.5420769461318843, 'colsample_bytree': 0.9412369220272623, 'reg_alpha': 8.52397418952234e-05, 'reg_lambda': 1.9793240638452266e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:31:48,618] Trial 87 finished with value: 0.7660491494714903 and parameters: {'n_estimators': 824, 'learning_rate': 0.07447885516451377, 'max_depth': 11, 'num_leaves': 62, 'min_child_samples': 84, 'subsample': 0.6020051020163084, 'colsample_bytree': 0.9162997924244577, 'reg_alpha': 3.3236511645464777, 'reg_lambda': 6.905404600403746e-08}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:32:53,733] Trial 88 finished with value: 0.771003184853892 and parameters: {'n_estimators': 901, 'learning_rate': 0.08614346301297114, 'max_depth': 5, 'num_leaves': 68, 'min_child_samples': 98, 'subsample': 0.6737140361386618, 'colsample_bytree': 0.982557235946273, 'reg_alpha': 1.1739323829512415e-07, 'reg_lambda': 3.0189947273712194}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:33:38,614] Trial 89 finished with value: 0.778017004161746 and parameters: {'n_estimators': 772, 'learning_rate': 0.0791908474417116, 'max_depth': 3, 'num_leaves': 73, 'min_child_samples': 91, 'subsample': 0.5173508056350818, 'colsample_bytree': 0.9366976557935521, 'reg_alpha': 0.0001728272272669296, 'reg_lambda': 4.058032740780818e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:34:19,200] Trial 90 finished with value: 0.7764293024309079 and parameters: {'n_estimators': 770, 'learning_rate': 0.14234018464132495, 'max_depth': 3, 'num_leaves': 80, 'min_child_samples': 92, 'subsample': 0.5183593815931758, 'colsample_bytree': 0.9550761483739306, 'reg_alpha': 5.000383368787074e-05, 'reg_lambda': 5.879819831301629e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:34:56,098] Trial 91 finished with value: 0.7778686457143292 and parameters: {'n_estimators': 852, 'learning_rate': 0.07875771292348221, 'max_depth': 3, 'num_leaves': 75, 'min_child_samples': 89, 'subsample': 0.5317464917688878, 'colsample_bytree': 0.9385113193736794, 'reg_alpha': 0.0002382757429394641, 'reg_lambda': 2.660679622606344e-07}. Best is trial 74 with value: 0.7780299106284778.
# [I 2025-11-13 16:35:31,910] Trial 92 finished with value: 0.7781511271647676 and parameters: {'n_estimators': 853, 'learning_rate': 0.07907543139500715, 'max_depth': 3, 'num_leaves': 73, 'min_child_samples': 88, 'subsample': 0.5360739119478459, 'colsample_bytree': 0.9372308562329565, 'reg_alpha': 0.0001648126458878349, 'reg_lambda': 1.1199809978194394e-06}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:36:17,207] Trial 93 finished with value: 0.7774735861146722 and parameters: {'n_estimators': 860, 'learning_rate': 0.09170195821581968, 'max_depth': 3, 'num_leaves': 76, 'min_child_samples': 88, 'subsample': 0.5367069254704896, 'colsample_bytree': 0.9363101118796919, 'reg_alpha': 0.00019839908904076172, 'reg_lambda': 1.1331595853803532e-06}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:36:55,405] Trial 94 finished with value: 0.7777954285911114 and parameters: {'n_estimators': 802, 'learning_rate': 0.0786017953599016, 'max_depth': 3, 'num_leaves': 71, 'min_child_samples': 85, 'subsample': 0.5326873845163629, 'colsample_bytree': 0.88935567836613, 'reg_alpha': 0.04570051118782949, 'reg_lambda': 3.611317224851824e-07}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:37:40,512] Trial 95 finished with value: 0.7774393427050527 and parameters: {'n_estimators': 933, 'learning_rate': 0.09623148242741003, 'max_depth': 3, 'num_leaves': 73, 'min_child_samples': 91, 'subsample': 0.5813747037279027, 'colsample_bytree': 0.9162865585244017, 'reg_alpha': 0.0008766833056122808, 'reg_lambda': 2.4593252185940124e-07}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:38:23,902] Trial 96 finished with value: 0.7781146772841708 and parameters: {'n_estimators': 868, 'learning_rate': 0.07091474062429405, 'max_depth': 3, 'num_leaves': 66, 'min_child_samples': 82, 'subsample': 0.5009670034101684, 'colsample_bytree': 0.9703532843033763, 'reg_alpha': 0.00031042381019906235, 'reg_lambda': 2.2683127218133797e-06}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:39:08,323] Trial 97 finished with value: 0.7779372333051512 and parameters: {'n_estimators': 982, 'learning_rate': 0.07293408963548073, 'max_depth': 3, 'num_leaves': 63, 'min_child_samples': 88, 'subsample': 0.5131534894952614, 'colsample_bytree': 0.9894201662053076, 'reg_alpha': 0.00015480038419656946, 'reg_lambda': 2.3808657291050846e-06}. Best is trial 92 with value: 0.7781511271647676.
# [I 2025-11-13 16:39:54,013] Trial 98 finished with value: 0.7781748286988392 and parameters: {'n_estimators': 982, 'learning_rate': 0.07078076256200418, 'max_depth': 3, 'num_leaves': 66, 'min_child_samples': 82, 'subsample': 0.5088717433655228, 'colsample_bytree': 0.9673826458690292, 'reg_alpha': 0.0001682151256450671, 'reg_lambda': 2.5289687929778095e-06}. Best is trial 98 with value: 0.7781748286988392.
# [I 2025-11-13 16:40:42,183] Trial 99 finished with value: 0.7783203146139892 and parameters: {'n_estimators': 981, 'learning_rate': 0.0701261784638505, 'max_depth': 3, 'num_leaves': 50, 'min_child_samples': 77, 'subsample': 0.5022449878003225, 'colsample_bytree': 0.9670688728186712, 'reg_alpha': 0.0005469072612312737, 'reg_lambda': 2.5536050141966927e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:41:32,575] Trial 100 finished with value: 0.7781305971908976 and parameters: {'n_estimators': 945, 'learning_rate': 0.0689814333680819, 'max_depth': 3, 'num_leaves': 41, 'min_child_samples': 76, 'subsample': 0.5012953715571133, 'colsample_bytree': 0.9680905464563518, 'reg_alpha': 0.0005613743219325092, 'reg_lambda': 2.2708834687242046e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:42:15,958] Trial 101 finished with value: 0.7780084378945408 and parameters: {'n_estimators': 986, 'learning_rate': 0.07123830795750478, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 77, 'subsample': 0.5125405702522485, 'colsample_bytree': 0.9668621183799323, 'reg_alpha': 0.00045368226167205426, 'reg_lambda': 2.4164925670764857e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:43:01,040] Trial 102 finished with value: 0.7781774913746646 and parameters: {'n_estimators': 954, 'learning_rate': 0.07017801668056285, 'max_depth': 3, 'num_leaves': 39, 'min_child_samples': 77, 'subsample': 0.514565994289466, 'colsample_bytree': 0.9679182556457097, 'reg_alpha': 0.0005141191162753326, 'reg_lambda': 2.376838710057251e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:43:54,900] Trial 103 finished with value: 0.7781468744998175 and parameters: {'n_estimators': 993, 'learning_rate': 0.05938209611545062, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 77, 'subsample': 0.5144628570257548, 'colsample_bytree': 0.9712861366828865, 'reg_alpha': 0.0026277658985011582, 'reg_lambda': 1.81438226665643e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:44:43,598] Trial 104 finished with value: 0.777809520119795 and parameters: {'n_estimators': 982, 'learning_rate': 0.05877942500838664, 'max_depth': 3, 'num_leaves': 41, 'min_child_samples': 76, 'subsample': 0.5137298521239283, 'colsample_bytree': 0.9661577792815724, 'reg_alpha': 0.0023309960713807395, 'reg_lambda': 2.3604400339846776e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:45:33,259] Trial 105 finished with value: 0.7779598821530549 and parameters: {'n_estimators': 994, 'learning_rate': 0.06821183914184123, 'max_depth': 3, 'num_leaves': 34, 'min_child_samples': 69, 'subsample': 0.5116197601397042, 'colsample_bytree': 0.9996239651415079, 'reg_alpha': 0.00048695585037699556, 'reg_lambda': 1.9177163478806135e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:46:11,521] Trial 106 finished with value: 0.7780036892197384 and parameters: {'n_estimators': 950, 'learning_rate': 0.06359671567095533, 'max_depth': 3, 'num_leaves': 36, 'min_child_samples': 72, 'subsample': 0.5003915601645147, 'colsample_bytree': 0.9717066718461842, 'reg_alpha': 0.0005735728592538788, 'reg_lambda': 1.5811195472352836e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:47:31,925] Trial 107 finished with value: 0.7674399872149072 and parameters: {'n_estimators': 946, 'learning_rate': 0.06252040902892522, 'max_depth': 9, 'num_leaves': 40, 'min_child_samples': 71, 'subsample': 0.5239404829544924, 'colsample_bytree': 0.9724908767659387, 'reg_alpha': 0.0036326019103028132, 'reg_lambda': 3.463211127561395e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:48:16,768] Trial 108 finished with value: 0.7780514363682826 and parameters: {'n_estimators': 967, 'learning_rate': 0.06536815944407971, 'max_depth': 3, 'num_leaves': 46, 'min_child_samples': 79, 'subsample': 0.5003721368881037, 'colsample_bytree': 0.976643733836382, 'reg_alpha': 0.0006281993094354105, 'reg_lambda': 9.513433344975198e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:49:05,575] Trial 109 finished with value: 0.7778770246021594 and parameters: {'n_estimators': 967, 'learning_rate': 0.056929129532306486, 'max_depth': 3, 'num_leaves': 47, 'min_child_samples': 80, 'subsample': 0.551581637331801, 'colsample_bytree': 0.959359447176942, 'reg_alpha': 0.00034266325364800174, 'reg_lambda': 1.1854210178393956e-05}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:49:47,531] Trial 110 finished with value: 0.7778097296132248 and parameters: {'n_estimators': 910, 'learning_rate': 0.06985991578549904, 'max_depth': 3, 'num_leaves': 44, 'min_child_samples': 78, 'subsample': 0.5208501282957336, 'colsample_bytree': 0.9283237249415811, 'reg_alpha': 0.002089316168234338, 'reg_lambda': 8.938090642352594e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:50:29,967] Trial 111 finished with value: 0.7779403905953652 and parameters: {'n_estimators': 946, 'learning_rate': 0.06525980716666224, 'max_depth': 3, 'num_leaves': 37, 'min_child_samples': 74, 'subsample': 0.501721590620695, 'colsample_bytree': 0.975277016189218, 'reg_alpha': 0.0007004224229448367, 'reg_lambda': 1.6251656642752614e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:51:18,120] Trial 112 finished with value: 0.7778652739447768 and parameters: {'n_estimators': 980, 'learning_rate': 0.06249290316303209, 'max_depth': 3, 'num_leaves': 50, 'min_child_samples': 67, 'subsample': 0.5027735010142557, 'colsample_bytree': 0.9462848171208947, 'reg_alpha': 0.000995156463862623, 'reg_lambda': 7.907473261854045e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:52:26,232] Trial 113 finished with value: 0.7734792948474964 and parameters: {'n_estimators': 932, 'learning_rate': 0.051013374322632976, 'max_depth': 7, 'num_leaves': 29, 'min_child_samples': 73, 'subsample': 0.5253918477488615, 'colsample_bytree': 0.9918283428449552, 'reg_alpha': 0.000546636867116659, 'reg_lambda': 1.2460102081344868e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:53:09,441] Trial 114 finished with value: 0.7778747892926419 and parameters: {'n_estimators': 996, 'learning_rate': 0.08511710401147506, 'max_depth': 3, 'num_leaves': 38, 'min_child_samples': 82, 'subsample': 0.5112772253969922, 'colsample_bytree': 0.964478017745261, 'reg_alpha': 0.003391234788184341, 'reg_lambda': 3.3842000711836428e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:53:59,441] Trial 115 finished with value: 0.7777308148334952 and parameters: {'n_estimators': 953, 'learning_rate': 0.05461299000181058, 'max_depth': 3, 'num_leaves': 48, 'min_child_samples': 79, 'subsample': 0.5010152222265144, 'colsample_bytree': 0.9748416573674316, 'reg_alpha': 0.0003301622615082299, 'reg_lambda': 7.624539253030953e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:54:36,546] Trial 116 finished with value: 0.7782611693709075 and parameters: {'n_estimators': 972, 'learning_rate': 0.0698434011217771, 'max_depth': 3, 'num_leaves': 44, 'min_child_samples': 75, 'subsample': 0.5323675822057619, 'colsample_bytree': 0.5048275932099457, 'reg_alpha': 0.0011484446906384843, 'reg_lambda': 5.232477039676841e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:55:25,571] Trial 117 finished with value: 0.7765823931350753 and parameters: {'n_estimators': 978, 'learning_rate': 0.07057575410657235, 'max_depth': 4, 'num_leaves': 44, 'min_child_samples': 75, 'subsample': 0.5581815440745779, 'colsample_bytree': 0.5169513520893063, 'reg_alpha': 0.005027216166843732, 'reg_lambda': 9.232391808101358e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:55:58,820] Trial 118 finished with value: 0.7780338256595514 and parameters: {'n_estimators': 923, 'learning_rate': 0.058434837771422166, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 77, 'subsample': 0.5394029115809036, 'colsample_bytree': 0.5430240403621182, 'reg_alpha': 0.0015655872912946455, 'reg_lambda': 4.978672389481251e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:56:41,192] Trial 119 finished with value: 0.7763149677365788 and parameters: {'n_estimators': 905, 'learning_rate': 0.07846179361457123, 'max_depth': 4, 'num_leaves': 50, 'min_child_samples': 80, 'subsample': 0.5381676173345203, 'colsample_bytree': 0.5493458491708623, 'reg_alpha': 0.010065933263636969, 'reg_lambda': 5.270364315678577e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:57:16,872] Trial 120 finished with value: 0.7776789987145042 and parameters: {'n_estimators': 928, 'learning_rate': 0.05747965697420578, 'max_depth': 3, 'num_leaves': 42, 'min_child_samples': 62, 'subsample': 0.5669130183605948, 'colsample_bytree': 0.5082183099988523, 'reg_alpha': 0.0019802192085505155, 'reg_lambda': 8.470715848509371e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:58:08,994] Trial 121 finished with value: 0.7782360265397232 and parameters: {'n_estimators': 999, 'learning_rate': 0.06772244977829761, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 77, 'subsample': 0.5209304989572233, 'colsample_bytree': 0.5636842317405065, 'reg_alpha': 0.0011904799737214857, 'reg_lambda': 4.3055896814251395e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:58:47,940] Trial 122 finished with value: 0.7780060221119044 and parameters: {'n_estimators': 962, 'learning_rate': 0.05998344833307293, 'max_depth': 3, 'num_leaves': 46, 'min_child_samples': 83, 'subsample': 0.5274490096170822, 'colsample_bytree': 0.532286080177369, 'reg_alpha': 0.001249425190435947, 'reg_lambda': 4.093751533840983e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 16:59:25,234] Trial 123 finished with value: 0.7778148947760851 and parameters: {'n_estimators': 888, 'learning_rate': 0.06622006162675506, 'max_depth': 3, 'num_leaves': 40, 'min_child_samples': 76, 'subsample': 0.5462139068102346, 'colsample_bytree': 0.603189840632999, 'reg_alpha': 0.0011311762044133003, 'reg_lambda': 5.097750253673092e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:00:02,775] Trial 124 finished with value: 0.7778970174335835 and parameters: {'n_estimators': 937, 'learning_rate': 0.08364873088006636, 'max_depth': 3, 'num_leaves': 34, 'min_child_samples': 81, 'subsample': 0.5201937064848332, 'colsample_bytree': 0.5606432398284118, 'reg_alpha': 0.0002923293153615115, 'reg_lambda': 1.0791142947838137e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:00:34,200] Trial 125 finished with value: 0.7781964980119858 and parameters: {'n_estimators': 971, 'learning_rate': 0.07633429259150709, 'max_depth': 3, 'num_leaves': 39, 'min_child_samples': 78, 'subsample': 0.5344654669140617, 'colsample_bytree': 0.5363166308532821, 'reg_alpha': 0.004480870048339258, 'reg_lambda': 5.131896133537065e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:01:14,019] Trial 126 finished with value: 0.7774322984865282 and parameters: {'n_estimators': 917, 'learning_rate': 0.04975350571434291, 'max_depth': 3, 'num_leaves': 39, 'min_child_samples': 77, 'subsample': 0.5349957412275406, 'colsample_bytree': 0.5409423032797924, 'reg_alpha': 0.004351472834572849, 'reg_lambda': 2.4544618966691646e-05}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:01:56,985] Trial 127 finished with value: 0.7760341502400561 and parameters: {'n_estimators': 967, 'learning_rate': 0.07440026197355994, 'max_depth': 4, 'num_leaves': 49, 'min_child_samples': 74, 'subsample': 0.5533070834266773, 'colsample_bytree': 0.50299107915291, 'reg_alpha': 0.012013889160286728, 'reg_lambda': 5.442026583048773e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:02:40,822] Trial 128 finished with value: 0.7778755691161019 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05995802214077691, 'max_depth': 3, 'num_leaves': 45, 'min_child_samples': 79, 'subsample': 0.5288352696566787, 'colsample_bytree': 0.5780800807844532, 'reg_alpha': 0.0006795576730415698, 'reg_lambda': 2.8000379442471e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:03:24,516] Trial 129 finished with value: 0.7776114408679987 and parameters: {'n_estimators': 953, 'learning_rate': 0.054499668541680674, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 67, 'subsample': 0.5377940831329308, 'colsample_bytree': 0.5317363920357661, 'reg_alpha': 0.001996995290225285, 'reg_lambda': 1.442438055401757e-05}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:04:13,146] Trial 130 finished with value: 0.7770828042151761 and parameters: {'n_estimators': 976, 'learning_rate': 0.0685776010016341, 'max_depth': 4, 'num_leaves': 51, 'min_child_samples': 84, 'subsample': 0.5136375626005237, 'colsample_bytree': 0.5643944594253918, 'reg_alpha': 0.0026326922637506427, 'reg_lambda': 1.5627758530328965e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:04:53,210] Trial 131 finished with value: 0.7778482005905697 and parameters: {'n_estimators': 933, 'learning_rate': 0.07879271702978213, 'max_depth': 3, 'num_leaves': 46, 'min_child_samples': 76, 'subsample': 0.5217623984813046, 'colsample_bytree': 0.6319619036616364, 'reg_alpha': 0.00014359548456667798, 'reg_lambda': 4.419157447942434e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:05:28,852] Trial 132 finished with value: 0.7780166037431704 and parameters: {'n_estimators': 902, 'learning_rate': 0.06514508728570995, 'max_depth': 3, 'num_leaves': 41, 'min_child_samples': 70, 'subsample': 0.5093533289306679, 'colsample_bytree': 0.522102388444803, 'reg_alpha': 0.0002413166451221738, 'reg_lambda': 6.693117708704504e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:06:24,742] Trial 133 finished with value: 0.777921046204865 and parameters: {'n_estimators': 959, 'learning_rate': 0.08341168056592209, 'max_depth': 3, 'num_leaves': 32, 'min_child_samples': 85, 'subsample': 0.543508089901164, 'colsample_bytree': 0.9496577184441545, 'reg_alpha': 0.0007821368532344258, 'reg_lambda': 1.179133310044366e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:07:09,916] Trial 134 finished with value: 0.7684058203736093 and parameters: {'n_estimators': 917, 'learning_rate': 0.013496109456268841, 'max_depth': 3, 'num_leaves': 38, 'min_child_samples': 78, 'subsample': 0.5194333191637192, 'colsample_bytree': 0.5500059199700916, 'reg_alpha': 0.001440320347565205, 'reg_lambda': 4.6609107852277736e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:08:02,699] Trial 135 finished with value: 0.7782937716581706 and parameters: {'n_estimators': 998, 'learning_rate': 0.07472843689316626, 'max_depth': 3, 'num_leaves': 42, 'min_child_samples': 81, 'subsample': 0.5003103385647558, 'colsample_bytree': 0.9337245182588609, 'reg_alpha': 0.00013529780247936612, 'reg_lambda': 7.822869626889695e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:09:16,208] Trial 136 finished with value: 0.7756592347614107 and parameters: {'n_estimators': 995, 'learning_rate': 0.07408215215127094, 'max_depth': 4, 'num_leaves': 45, 'min_child_samples': 82, 'subsample': 0.5610417370351473, 'colsample_bytree': 0.982544707311345, 'reg_alpha': 0.0003729011942225064, 'reg_lambda': 7.661553335544865e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:09:58,974] Trial 137 finished with value: 0.7777683415983109 and parameters: {'n_estimators': 972, 'learning_rate': 0.06869094786188046, 'max_depth': 3, 'num_leaves': 43, 'min_child_samples': 72, 'subsample': 0.5080740360678716, 'colsample_bytree': 0.5155419213597093, 'reg_alpha': 4.209234223093966e-05, 'reg_lambda': 1.8934010853047084e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:10:40,074] Trial 138 finished with value: 0.7777549066806562 and parameters: {'n_estimators': 950, 'learning_rate': 0.08839942052459339, 'max_depth': 3, 'num_leaves': 39, 'min_child_samples': 86, 'subsample': 0.5300797909285716, 'colsample_bytree': 0.5807526376205845, 'reg_alpha': 0.00012936232206744048, 'reg_lambda': 3.472550252078653e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:11:39,032] Trial 139 finished with value: 0.776672346882523 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06113854822810978, 'max_depth': 4, 'num_leaves': 36, 'min_child_samples': 80, 'subsample': 0.5492849389487474, 'colsample_bytree': 0.9574646806338025, 'reg_alpha': 0.02236756762265405, 'reg_lambda': 9.391407225582003e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:12:28,080] Trial 140 finished with value: 0.7774692344263562 and parameters: {'n_estimators': 877, 'learning_rate': 0.056889018298268916, 'max_depth': 3, 'num_leaves': 48, 'min_child_samples': 75, 'subsample': 0.50014621595872, 'colsample_bytree': 0.9889118375227651, 'reg_alpha': 6.20303158195736e-05, 'reg_lambda': 1.2428256066025554e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:13:09,644] Trial 141 finished with value: 0.7778954598237169 and parameters: {'n_estimators': 974, 'learning_rate': 0.07834048076879395, 'max_depth': 3, 'num_leaves': 42, 'min_child_samples': 78, 'subsample': 0.5151131116079646, 'colsample_bytree': 0.9362073440232775, 'reg_alpha': 0.00019207226694181793, 'reg_lambda': 2.2192112335335035e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:13:26,979] Trial 142 finished with value: 0.7740260909467713 and parameters: {'n_estimators': 325, 'learning_rate': 0.07252189323089903, 'max_depth': 3, 'num_leaves': 66, 'min_child_samples': 83, 'subsample': 0.5236071616374198, 'colsample_bytree': 0.9320596519715194, 'reg_alpha': 0.0005746381150590462, 'reg_lambda': 7.542762445327738e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:14:13,401] Trial 143 finished with value: 0.7781524219557514 and parameters: {'n_estimators': 933, 'learning_rate': 0.06566390994524535, 'max_depth': 3, 'num_leaves': 40, 'min_child_samples': 81, 'subsample': 0.5335330030004624, 'colsample_bytree': 0.9519265715508003, 'reg_alpha': 0.0010015138362094611, 'reg_lambda': 2.152763172811066e-07}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:15:01,014] Trial 144 finished with value: 0.7781027228291221 and parameters: {'n_estimators': 931, 'learning_rate': 0.06521632704882822, 'max_depth': 3, 'num_leaves': 40, 'min_child_samples': 80, 'subsample': 0.537206450845533, 'colsample_bytree': 0.9476673552249463, 'reg_alpha': 0.0009483941025521009, 'reg_lambda': 2.948526599420366e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:15:48,832] Trial 145 finished with value: 0.7779496886524864 and parameters: {'n_estimators': 940, 'learning_rate': 0.06361848337314656, 'max_depth': 3, 'num_leaves': 42, 'min_child_samples': 81, 'subsample': 0.5780044306286117, 'colsample_bytree': 0.9460935885395861, 'reg_alpha': 0.0013726499674183731, 'reg_lambda': 5.53963051461783e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:16:30,662] Trial 146 finished with value: 0.7773446940784211 and parameters: {'n_estimators': 919, 'learning_rate': 0.05249171904231214, 'max_depth': 3, 'num_leaves': 40, 'min_child_samples': 77, 'subsample': 0.5355247996298419, 'colsample_bytree': 0.9134725739844359, 'reg_alpha': 0.0031357299125460837, 'reg_lambda': 2.707906618425225e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:17:33,214] Trial 147 finished with value: 0.7780634764060684 and parameters: {'n_estimators': 981, 'learning_rate': 0.0660207228103416, 'max_depth': 3, 'num_leaves': 38, 'min_child_samples': 74, 'subsample': 0.5433059561613451, 'colsample_bytree': 0.9575152945442983, 'reg_alpha': 0.005908602835012584, 'reg_lambda': 1.785954321229605e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:18:27,782] Trial 148 finished with value: 0.7780167028624619 and parameters: {'n_estimators': 962, 'learning_rate': 0.0673136810707246, 'max_depth': 3, 'num_leaves': 32, 'min_child_samples': 74, 'subsample': 0.5708692566858073, 'colsample_bytree': 0.9603312144163149, 'reg_alpha': 0.005343075291830135, 'reg_lambda': 1.6505166181909842e-06}. Best is trial 99 with value: 0.7783203146139892.
# [I 2025-11-13 17:19:08,853] Trial 149 finished with value: 0.7777823576451565 and parameters: {'n_estimators': 988, 'learning_rate': 0.07196812395892054, 'max_depth': 3, 'num_leaves': 35, 'min_child_samples': 80, 'subsample': 0.5538373570515418, 'colsample_bytree': 0.9485789297774635, 'reg_alpha': 0.00781527486700686, 'reg_lambda': 3.5381156708471155e-06}. Best is trial 99 with value: 0.7783203146139892.
#
# Best trial:
#   Value (CV AUC): 0.7783
#   Params:
#     n_estimators: 981
#     learning_rate: 0.0701261784638505
#     max_depth: 3
#     num_leaves: 50
#     min_child_samples: 77
#     subsample: 0.5022449878003225
#     colsample_bytree: 0.9670688728186712
#     reg_alpha: 0.0005469072612312737
#     reg_lambda: 2.5536050141966927e-06
# CPU times: total: 1min 23s
# Wall time: 2h 17min 14s

# %% [markdown]
# ### Train Final LightGBM with Best Params

# %%
# %%time

best_params_lgb = study_lgb.best_trial.params
best_params_lgb['class_weight'] = 'balanced'
best_params_lgb['random_state'] = 42
best_params_lgb['verbose'] = -1

lgb_tuned = LGBMClassifier(**best_params_lgb)
lgb_tuned.fit(X_train, y_train)

train_auc_lgb = roc_auc_score(y_train, lgb_tuned.predict_proba(X_train)[:, 1])
val_auc_lgb = roc_auc_score(y_val, lgb_tuned.predict_proba(X_val)[:, 1])

print("LightGBM Tuned Results:")
print(f"  Train AUC: {train_auc_lgb:.4f}")
print(f"  Val AUC: {val_auc_lgb:.4f}")
print(f"  Baseline CV AUC: {phase5_metadata['cv_eval']['lgb_cv_mean']:.4f}")
print(f"  Tuned CV AUC: {study_lgb.best_trial.value:.4f}")
print(f"  Improvement: {study_lgb.best_trial.value - phase5_metadata['cv_eval']['lgb_cv_mean']:.4f}")
# Out:
# LightGBM Tuned Results:
#   Train AUC: 0.8223
#   Val AUC: 0.7780
#   Baseline CV AUC: 0.7755
#   Tuned CV AUC: 0.7783
#   Improvement: 0.0028
# CPU times: total: 1min 33s
# Wall time: 12.2 s

# %% [markdown]
# ### XGBoost Hyperparameter Tuning

# %%
def xgb_objective(trial):
    scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
    
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'scale_pos_weight': scale_pos_weight,
        'random_state': 42,
        'verbosity': 0,
        'eval_metric': 'auc'
    }
    
    model = XGBClassifier(**params)
    
    X_full = pd.concat([X_train, X_val], axis=0).reset_index(drop=True)
    y_full = np.concatenate([y_train, y_val])
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_full, y_full, cv=cv, scoring='roc_auc', n_jobs=-1)
    
    return scores.mean()

print("XGBoost objective function defined")
# Out:
# XGBoost objective function defined

# %%
# %%time

study_xgb = optuna.create_study(
    direction='maximize',
    study_name='xgboost_tuning',
    sampler=optuna.samplers.TPESampler(seed=42),
    pruner=optuna.pruners.MedianPruner()
)

study_xgb.optimize(xgb_objective, n_trials=50, show_progress_bar=True, n_jobs=1)

print(f"\nBest trial:")
print(f"  Value (CV AUC): {study_xgb.best_trial.value:.4f}")
print(f"  Params: ")
for key, value in study_xgb.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-13 17:47:34,018] A new study created in memory with name: xgboost_tuning
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-13 17:49:24,974] Trial 0 finished with value: 0.7062873979233851 and parameters: {'n_estimators': 437, 'learning_rate': 0.2536999076681772, 'max_depth': 10, 'min_child_weight': 6, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 2.9152036385288193e-08, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598}. Best is trial 0 with value: 0.7062873979233851.
# [I 2025-11-13 17:55:02,104] Trial 1 finished with value: 0.7634962304109589 and parameters: {'n_estimators': 737, 'learning_rate': 0.010725209743171996, 'max_depth': 12, 'min_child_weight': 9, 'subsample': 0.6061695553391381, 'colsample_bytree': 0.5909124836035503, 'gamma': 2.9324868872723725e-07, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 1 with value: 0.7634962304109589.
# [I 2025-11-13 17:56:58,171] Trial 2 finished with value: 0.7633788426562494 and parameters: {'n_estimators': 489, 'learning_rate': 0.02692655251486473, 'max_depth': 9, 'min_child_weight': 2, 'subsample': 0.6460723242676091, 'colsample_bytree': 0.6831809216468459, 'gamma': 4.452048365748842e-05, 'reg_alpha': 0.1165691561324743, 'reg_lambda': 6.267062696005991e-07}. Best is trial 1 with value: 0.7634962304109589.
# [I 2025-11-13 17:57:36,552] Trial 3 finished with value: 0.7772476431877628 and parameters: {'n_estimators': 563, 'learning_rate': 0.07500118950416987, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.5852620618436457, 'colsample_bytree': 0.5325257964926398, 'gamma': 0.39001768308022033, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 17:59:19,879] Trial 4 finished with value: 0.7697944026193644 and parameters: {'n_estimators': 374, 'learning_rate': 0.013940346079873234, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.5610191174223894, 'colsample_bytree': 0.7475884550556351, 'gamma': 1.8841183049085085e-08, 'reg_alpha': 1.527156759251193, 'reg_lambda': 2.133142332373004e-06}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:01:33,371] Trial 5 finished with value: 0.7703750898519885 and parameters: {'n_estimators': 696, 'learning_rate': 0.028869220380495747, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.5924272277627636, 'colsample_bytree': 0.9847923138822793, 'gamma': 0.01588775693167255, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:02:11,241] Trial 6 finished with value: 0.7652118972333387 and parameters: {'n_estimators': 638, 'learning_rate': 0.22999586428143728, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.522613644455269, 'colsample_bytree': 0.6626651653816322, 'gamma': 1.2865252594826764e-05, 'reg_alpha': 2.7678419414850017e-06, 'reg_lambda': 0.28749982347407854}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:03:26,607] Trial 7 finished with value: 0.7718483209602005 and parameters: {'n_estimators': 421, 'learning_rate': 0.026000059117302653, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.9010984903770198, 'colsample_bytree': 0.5372753218398854, 'gamma': 0.7854083114461319, 'reg_alpha': 0.08916674715636537, 'reg_lambda': 6.143857495033091e-07}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:03:56,204] Trial 8 finished with value: 0.7424754864381486 and parameters: {'n_estimators': 104, 'learning_rate': 0.1601531217136121, 'max_depth': 10, 'min_child_weight': 8, 'subsample': 0.8856351733429728, 'colsample_bytree': 0.5370223258670452, 'gamma': 7.374385355858303e-06, 'reg_alpha': 1.1036250149900698e-07, 'reg_lambda': 0.5860448217200517}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:04:36,914] Trial 9 finished with value: 0.7741337224753915 and parameters: {'n_estimators': 661, 'learning_rate': 0.030816017044468066, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.6625916610133735, 'colsample_bytree': 0.864803089169032, 'gamma': 0.0012602588933700108, 'reg_alpha': 0.9658611176861268, 'reg_lambda': 0.0001778010520878397}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:05:53,318] Trial 10 finished with value: 0.7659189934006734 and parameters: {'n_estimators': 951, 'learning_rate': 0.09121222976475846, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.7595720016297407, 'colsample_bytree': 0.8451235367845726, 'gamma': 0.6090719118432153, 'reg_alpha': 0.0025074987853267337, 'reg_lambda': 0.008349484536843164}. Best is trial 3 with value: 0.7772476431877628.
# [I 2025-11-13 18:06:43,502] Trial 11 finished with value: 0.778144827872199 and parameters: {'n_estimators': 861, 'learning_rate': 0.06071618023039132, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.7171781358782057, 'colsample_bytree': 0.865042426595599, 'gamma': 0.00444970387513357, 'reg_alpha': 0.0029151336209232823, 'reg_lambda': 9.22101468409744e-05}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:08:01,155] Trial 12 finished with value: 0.7702793586632504 and parameters: {'n_estimators': 944, 'learning_rate': 0.06998137600951818, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.7566297445510356, 'colsample_bytree': 0.8682062473644429, 'gamma': 0.01538743084650485, 'reg_alpha': 0.0022340951163293166, 'reg_lambda': 3.0500140521049728e-05}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:09:10,947] Trial 13 finished with value: 0.7630055388040399 and parameters: {'n_estimators': 830, 'learning_rate': 0.10890699165380563, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.7084623041637503, 'colsample_bytree': 0.946278846830753, 'gamma': 0.024280082797654656, 'reg_alpha': 6.68470234340653e-05, 'reg_lambda': 0.024800628752107378}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:09:33,134] Trial 14 finished with value: 0.7739048909316297 and parameters: {'n_estimators': 261, 'learning_rate': 0.05250585676555691, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8155421717694825, 'colsample_bytree': 0.7658286222724009, 'gamma': 0.0009685716397693296, 'reg_alpha': 0.015936847132186974, 'reg_lambda': 1.8521134346522616e-05}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:11:01,935] Trial 15 finished with value: 0.7728384396199777 and parameters: {'n_estimators': 821, 'learning_rate': 0.06253506876520325, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.8202139292383122, 'colsample_bytree': 0.7807117976768776, 'gamma': 0.11573285558797254, 'reg_alpha': 9.784448394229303, 'reg_lambda': 6.243069797304142}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:12:05,507] Trial 16 finished with value: 0.7719643253257141 and parameters: {'n_estimators': 555, 'learning_rate': 0.045523232248988695, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.5036183344968538, 'colsample_bytree': 0.9205096274218562, 'gamma': 0.0012311257542169268, 'reg_alpha': 0.0001897403926656574, 'reg_lambda': 1.314053143275926e-08}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:12:25,963] Trial 17 finished with value: 0.7757414963262868 and parameters: {'n_estimators': 292, 'learning_rate': 0.12068708450004323, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6891588707528771, 'colsample_bytree': 0.6698716112206504, 'gamma': 0.1281159273993456, 'reg_alpha': 2.1219899323605756e-08, 'reg_lambda': 0.13457934870105304}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:13:35,831] Trial 18 finished with value: 0.7622176806947456 and parameters: {'n_estimators': 999, 'learning_rate': 0.16404313615925473, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.8153925651862834, 'colsample_bytree': 0.8070690085115645, 'gamma': 0.0003249358220948034, 'reg_alpha': 0.00881562598099981, 'reg_lambda': 0.0010393856849475972}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:15:00,820] Trial 19 finished with value: 0.773210075926037 and parameters: {'n_estimators': 818, 'learning_rate': 0.03904439995746737, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.6353627978150597, 'colsample_bytree': 0.7231610042250181, 'gamma': 0.005645440337907908, 'reg_alpha': 5.799449092292779e-05, 'reg_lambda': 0.02697463771372744}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:15:44,818] Trial 20 finished with value: 0.7715231080913365 and parameters: {'n_estimators': 574, 'learning_rate': 0.018783577169614107, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.9912616503334379, 'colsample_bytree': 0.6200392464368687, 'gamma': 0.11257594760992415, 'reg_alpha': 0.09355071860914736, 'reg_lambda': 8.802075014264656}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:16:04,112] Trial 21 finished with value: 0.7750213485349275 and parameters: {'n_estimators': 275, 'learning_rate': 0.09738335643224103, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.7062477381430202, 'colsample_bytree': 0.6598251560348384, 'gamma': 0.11377560288347334, 'reg_alpha': 1.4329321655479917e-08, 'reg_lambda': 0.08656709886297852}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:16:17,024] Trial 22 finished with value: 0.7734732562725434 and parameters: {'n_estimators': 155, 'learning_rate': 0.15624993268501192, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.7000214125868693, 'colsample_bytree': 0.5141431809357833, 'gamma': 0.2568053521047608, 'reg_alpha': 2.6635259319970187e-07, 'reg_lambda': 9.305755343565031e-05}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:16:41,890] Trial 23 finished with value: 0.776080063595697 and parameters: {'n_estimators': 278, 'learning_rate': 0.07926336732109561, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.6878566329073507, 'colsample_bytree': 0.7003935843274606, 'gamma': 0.006328377788871549, 'reg_alpha': 1.9303309067868627e-06, 'reg_lambda': 0.005082962821793838}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:17:08,419] Trial 24 finished with value: 0.7768728867878092 and parameters: {'n_estimators': 339, 'learning_rate': 0.07342841430560802, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.7413740950547056, 'colsample_bytree': 0.8211338116630438, 'gamma': 0.004025491416975599, 'reg_alpha': 2.6805070936504677e-06, 'reg_lambda': 0.004380274208339267}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:17:59,182] Trial 25 finished with value: 0.7677165264589069 and parameters: {'n_estimators': 356, 'learning_rate': 0.0645165080341248, 'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.7775920855448069, 'colsample_bytree': 0.9145942595193252, 'gamma': 6.675709591176246e-05, 'reg_alpha': 2.2546182950005623e-05, 'reg_lambda': 8.664564190305589e-06}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:19:04,052] Trial 26 finished with value: 0.776348900243729 and parameters: {'n_estimators': 762, 'learning_rate': 0.04276103247010874, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8654999282136744, 'colsample_bytree': 0.8170659314221973, 'gamma': 0.00021728492831285916, 'reg_alpha': 0.0011118949664853917, 'reg_lambda': 0.03090031432387847}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:19:40,337] Trial 27 finished with value: 0.7768345519258874 and parameters: {'n_estimators': 490, 'learning_rate': 0.08020677723875473, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.7316378147748782, 'colsample_bytree': 0.8980928761881997, 'gamma': 0.003743071968899455, 'reg_alpha': 0.00038469360959708117, 'reg_lambda': 0.0012337169452740562}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:20:17,458] Trial 28 finished with value: 0.7756592699617842 and parameters: {'n_estimators': 602, 'learning_rate': 0.12286074158300235, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.5566360920552389, 'colsample_bytree': 0.8290518662306083, 'gamma': 0.03402647021141705, 'reg_alpha': 1.658627703824338e-07, 'reg_lambda': 2.268222869528505}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:21:23,625] Trial 29 finished with value: 0.7125568603841874 and parameters: {'n_estimators': 479, 'learning_rate': 0.2746882746974813, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.6255014540703181, 'colsample_bytree': 0.9884268395613129, 'gamma': 5.319087504190791e-07, 'reg_alpha': 1.1904076911383756e-05, 'reg_lambda': 0.003841986199790999}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:21:42,133] Trial 30 finished with value: 0.7707938908771894 and parameters: {'n_estimators': 201, 'learning_rate': 0.05132032065166573, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9558460102215038, 'colsample_bytree': 0.7949866834933749, 'gamma': 0.0004375750415733456, 'reg_alpha': 6.78843756076599e-07, 'reg_lambda': 0.00010290600776710145}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:22:18,909] Trial 31 finished with value: 0.7771857257715734 and parameters: {'n_estimators': 484, 'learning_rate': 0.07932865731705177, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.7379430895111594, 'colsample_bytree': 0.8972868243132827, 'gamma': 0.0041717505337783255, 'reg_alpha': 0.0005606188920026493, 'reg_lambda': 0.0009443834856466253}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:25:39,639] Trial 32 finished with value: 0.7317522547480346 and parameters: {'n_estimators': 426, 'learning_rate': 0.05943393336233198, 'max_depth': 12, 'min_child_weight': 4, 'subsample': 0.7884526658388936, 'colsample_bytree': 0.8825046721613448, 'gamma': 0.0034582676481275114, 'reg_alpha': 0.01501981961556658, 'reg_lambda': 0.0006123984686569385}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:26:14,051] Trial 33 finished with value: 0.7755614204873786 and parameters: {'n_estimators': 352, 'learning_rate': 0.03630070902101169, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.7361200393005878, 'colsample_bytree': 0.8464497852296041, 'gamma': 2.1573417048061966e-05, 'reg_alpha': 0.2065489402076621, 'reg_lambda': 0.00031665603198491104}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:26:51,215] Trial 34 finished with value: 0.776977201673192 and parameters: {'n_estimators': 502, 'learning_rate': 0.07861086443687218, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6640253143746593, 'colsample_bytree': 0.9439951646515489, 'gamma': 4.6244502790472146e-06, 'reg_alpha': 0.0003962404413020296, 'reg_lambda': 0.011018583142013672}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:27:22,733] Trial 35 finished with value: 0.7772596850177971 and parameters: {'n_estimators': 505, 'learning_rate': 0.09006427162930543, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.6630387382137706, 'colsample_bytree': 0.9520026728957132, 'gamma': 1.8899394226538414e-06, 'reg_alpha': 0.0006214279945959046, 'reg_lambda': 0.012739640923539191}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:28:04,984] Trial 36 finished with value: 0.7671568948970533 and parameters: {'n_estimators': 706, 'learning_rate': 0.2129591039152563, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.5860506310722081, 'colsample_bytree': 0.9565558207060557, 'gamma': 1.6249058888265463e-06, 'reg_alpha': 0.005992057128142106, 'reg_lambda': 0.17962249395647956}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:28:42,197] Trial 37 finished with value: 0.7745919981943754 and parameters: {'n_estimators': 617, 'learning_rate': 0.1366142389529452, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.5642172125113806, 'colsample_bytree': 0.6002040815498728, 'gamma': 7.120501837127167e-08, 'reg_alpha': 0.029708613713087594, 'reg_lambda': 1.863322190925038e-06}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:31:22,534] Trial 38 finished with value: 0.7357018243852336 and parameters: {'n_estimators': 523, 'learning_rate': 0.09993425265071092, 'max_depth': 11, 'min_child_weight': 9, 'subsample': 0.604460571182802, 'colsample_bytree': 0.9588165979252317, 'gamma': 7.214249441384564e-08, 'reg_alpha': 9.3855115716275e-05, 'reg_lambda': 0.061101932272650566}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:31:51,905] Trial 39 finished with value: 0.7756054995490693 and parameters: {'n_estimators': 456, 'learning_rate': 0.05349104011302249, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6600079384857852, 'colsample_bytree': 0.9185382432186658, 'gamma': 0.0001568538933525929, 'reg_alpha': 0.3380665827083777, 'reg_lambda': 0.6170109783172248}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:35:16,456] Trial 40 finished with value: 0.7640694458197929 and parameters: {'n_estimators': 871, 'learning_rate': 0.022923104075560072, 'max_depth': 9, 'min_child_weight': 6, 'subsample': 0.5443208538253995, 'colsample_bytree': 0.9863884291210855, 'gamma': 1.02707011913726e-08, 'reg_alpha': 2.388192350088717, 'reg_lambda': 0.0012540808089860464}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:35:46,632] Trial 41 finished with value: 0.7764482889992301 and parameters: {'n_estimators': 392, 'learning_rate': 0.0866312889928318, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6642435232374758, 'colsample_bytree': 0.9398886292136619, 'gamma': 2.949715231480072e-06, 'reg_alpha': 0.0005415849866148804, 'reg_lambda': 0.011178780195084188}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:36:32,989] Trial 42 finished with value: 0.7738110281657918 and parameters: {'n_estimators': 523, 'learning_rate': 0.06802289859269475, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.6141482161102854, 'colsample_bytree': 0.8930325635117086, 'gamma': 5.12733226013957e-06, 'reg_alpha': 0.0010544535710025583, 'reg_lambda': 0.002018805225313637}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:37:12,827] Trial 43 finished with value: 0.7772509908439303 and parameters: {'n_estimators': 668, 'learning_rate': 0.08636796710861969, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.6478330360413643, 'colsample_bytree': 0.9679966693964525, 'gamma': 2.6683143204015288e-05, 'reg_alpha': 0.0038587493582267203, 'reg_lambda': 0.014595465727768337}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:37:58,547] Trial 44 finished with value: 0.7621209615580731 and parameters: {'n_estimators': 666, 'learning_rate': 0.010661223528944611, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.637275765479607, 'colsample_bytree': 0.999419718541817, 'gamma': 2.7521858934936407e-05, 'reg_alpha': 0.04229172880216516, 'reg_lambda': 4.117698863155001e-05}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:38:34,641] Trial 45 finished with value: 0.7775032119747884 and parameters: {'n_estimators': 576, 'learning_rate': 0.10204806219598873, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.7179923450217305, 'colsample_bytree': 0.9688310483927279, 'gamma': 8.084961796934633e-07, 'reg_alpha': 0.0035606042019631677, 'reg_lambda': 0.0002573262158086367}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:42:19,056] Trial 46 finished with value: 0.7198822918797946 and parameters: {'n_estimators': 762, 'learning_rate': 0.10834508323357386, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.6808557175670824, 'colsample_bytree': 0.7468672582786076, 'gamma': 5.002786945742774e-07, 'reg_alpha': 0.004858081727103198, 'reg_lambda': 0.00028040135884848906}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:42:54,317] Trial 47 finished with value: 0.7716400597160253 and parameters: {'n_estimators': 574, 'learning_rate': 0.2018301856971898, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7176876603709444, 'colsample_bytree': 0.9674964106685132, 'gamma': 1.6919774846306293e-06, 'reg_alpha': 0.0032277247612518094, 'reg_lambda': 0.499649130444721}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:43:38,139] Trial 48 finished with value: 0.7716096188728614 and parameters: {'n_estimators': 703, 'learning_rate': 0.1775190944464579, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.5890779357467166, 'colsample_bytree': 0.972773027957591, 'gamma': 1.489161715556065e-05, 'reg_alpha': 0.7811216940950746, 'reg_lambda': 9.351599696361347e-06}. Best is trial 11 with value: 0.778144827872199.
# [I 2025-11-13 18:44:35,655] Trial 49 finished with value: 0.7641284744159929 and parameters: {'n_estimators': 645, 'learning_rate': 0.13075754060837746, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.7732835354715532, 'colsample_bytree': 0.9279093331446431, 'gamma': 2.1200696680979194e-07, 'reg_alpha': 0.0014463489023570308, 'reg_lambda': 2.7680716342651883}. Best is trial 11 with value: 0.778144827872199.
#
# Best trial:
#   Value (CV AUC): 0.7781
#   Params:
#     n_estimators: 861
#     learning_rate: 0.06071618023039132
#     max_depth: 3
#     min_child_weight: 4
#     subsample: 0.7171781358782057
#     colsample_bytree: 0.865042426595599
#     gamma: 0.00444970387513357
#     reg_alpha: 0.0029151336209232823
#     reg_lambda: 9.22101468409744e-05
# CPU times: total: 23.8 s
# Wall time: 57min 1s

# %% [markdown]
# ### Train Final XGBoost with Best Params

# %%
# %%time

scale_pos_weight_xgb = (y_train == 0).sum() / (y_train == 1).sum()

best_params_xgb = study_xgb.best_trial.params
best_params_xgb['scale_pos_weight'] = scale_pos_weight_xgb
best_params_xgb['random_state'] = 42
best_params_xgb['verbosity'] = 0
best_params_xgb['eval_metric'] = 'auc'

xgb_tuned = XGBClassifier(**best_params_xgb)
xgb_tuned.fit(X_train, y_train)

train_auc_xgb = roc_auc_score(y_train, xgb_tuned.predict_proba(X_train)[:, 1])
val_auc_xgb = roc_auc_score(y_val, xgb_tuned.predict_proba(X_val)[:, 1])

print("XGBoost Tuned Results:")
print(f"  Train AUC: {train_auc_xgb:.4f}")
print(f"  Val AUC: {val_auc_xgb:.4f}")
print(f"  Baseline CV AUC: {phase5_metadata['cv_eval']['xgb_cv_mean']:.4f}")
print(f"  Tuned CV AUC: {study_xgb.best_trial.value:.4f}")
print(f"  Improvement: {study_xgb.best_trial.value - phase5_metadata['cv_eval']['xgb_cv_mean']:.4f}")
# Out:
# XGBoost Tuned Results:
#   Train AUC: 0.8157
#   Val AUC: 0.7781
#   Baseline CV AUC: 0.7674
#   Tuned CV AUC: 0.7781
#   Improvement: 0.0107
# CPU times: total: 2min 46s
# Wall time: 12.5 s

# %% [markdown]
# ### Model Comparison

# %%
comparison_df = pd.DataFrame({
    'Model': [
        'LightGBM Baseline',
        'LightGBM Tuned',
        'XGBoost Baseline',
        'XGBoost Tuned'
    ],
    'CV AUC': [
        phase5_metadata['cv_eval']['lgb_cv_mean'],
        study_lgb.best_trial.value,
        phase5_metadata['cv_eval']['xgb_cv_mean'],
        study_xgb.best_trial.value
    ],
    'Val AUC': [
        phase5_metadata['quick_eval']['lgb_val_auc'],
        val_auc_lgb,
        phase5_metadata['quick_eval']['xgb_val_auc'],
        val_auc_xgb
    ],
    'Train AUC': [
        phase5_metadata['quick_eval']['lgb_train_auc'],
        train_auc_lgb,
        phase5_metadata['quick_eval']['xgb_train_auc'],
        train_auc_xgb
    ]
})

comparison_df['CV Improvement'] = comparison_df['CV AUC'] - [
    phase5_metadata['cv_eval']['lgb_cv_mean'],
    phase5_metadata['cv_eval']['lgb_cv_mean'],
    phase5_metadata['cv_eval']['xgb_cv_mean'],
    phase5_metadata['cv_eval']['xgb_cv_mean']
]

print("\nModel Performance Comparison:")
print(comparison_df.to_string(index=False))
# Out:
# Model Performance Comparison:
#             Model   CV AUC  Val AUC  Train AUC  CV Improvement
# LightGBM Baseline 0.775505 0.776472   0.862449        0.000000
#    LightGBM Tuned 0.778320 0.777957   0.822262        0.002815
#  XGBoost Baseline 0.767399 0.767688   0.929613        0.000000
#     XGBoost Tuned 0.778145 0.778131   0.815673        0.010746

# %% [markdown]
# ### Kaggle Submission

# %%
lgb_preds = lgb_tuned.predict_proba(X_test)[:, 1]
xgb_preds = xgb_tuned.predict_proba(X_test)[:, 1]

submission_lgb = pd.DataFrame({
    'SK_ID_CURR': test_ids,
    'TARGET': lgb_preds
})

submission_xgb = pd.DataFrame({
    'SK_ID_CURR': test_ids,
    'TARGET': xgb_preds
})

os.makedirs('../../data/submissions', exist_ok=True)

submission_lgb.to_csv('../../data/submissions/tuned_lightgbm_v1.csv', index=False)
submission_xgb.to_csv('../../data/submissions/tuned_xgboost_v1.csv', index=False)

print("Submission files created:")
print("  tuned_lightgbm_v1.csv")
print("  tuned_xgboost_v1.csv")
print(f"\nLightGBM predictions - Min: {lgb_preds.min():.4f}, Max: {lgb_preds.max():.4f}, Mean: {lgb_preds.mean():.4f}")
print(f"XGBoost predictions  - Min: {xgb_preds.min():.4f}, Max: {xgb_preds.max():.4f}, Mean: {xgb_preds.mean():.4f}")
# Out:
# Submission files created:
#   tuned_lightgbm_v1.csv
#   tuned_xgboost_v1.csv
#
# LightGBM predictions - Min: 0.0035, Max: 0.9777, Mean: 0.3703
# XGBoost predictions  - Min: 0.0057, Max: 0.9758, Mean: 0.3723

# %% [markdown]
# ### MLflow Tracking

# %%
mlflow_tracking_uri = os.path.join(os.getcwd(), 'mlruns')
mlflow.set_tracking_uri(f"file:///{mlflow_tracking_uri}")

mlflow.set_experiment("model_optimization")

with mlflow.start_run(run_name="lightgbm_tuned"):
    mlflow.log_params(best_params_lgb)
    mlflow.log_param("n_features", X_train.shape[1])
    mlflow.log_param("n_trials", 150)
    
    mlflow.log_metric("train_auc", train_auc_lgb)
    mlflow.log_metric("val_auc", val_auc_lgb)
    mlflow.log_metric("cv_auc", study_lgb.best_trial.value)
    mlflow.log_metric("baseline_cv_auc", phase5_metadata['cv_eval']['lgb_cv_mean'])
    mlflow.log_metric("improvement", study_lgb.best_trial.value - phase5_metadata['cv_eval']['lgb_cv_mean'])
    
    X_sample = X_train.iloc[:5]
    y_sample = y_train[:5]
    signature = infer_signature(X_sample, y_sample)
    mlflow.sklearn.log_model(lgb_tuned, "model", signature=signature, input_example=X_sample)

print("Logged LightGBM tuned model to MLflow")

with mlflow.start_run(run_name="xgboost_tuned"):
    mlflow.log_params(best_params_xgb)
    mlflow.log_param("n_features", X_train.shape[1])
    mlflow.log_param("n_trials", 150)
    
    mlflow.log_metric("train_auc", train_auc_xgb)
    mlflow.log_metric("val_auc", val_auc_xgb)
    mlflow.log_metric("cv_auc", study_xgb.best_trial.value)
    mlflow.log_metric("baseline_cv_auc", phase5_metadata['cv_eval']['xgb_cv_mean'])
    mlflow.log_metric("improvement", study_xgb.best_trial.value - phase5_metadata['cv_eval']['xgb_cv_mean'])
    
    X_sample = X_train.iloc[:5]
    y_sample = y_train[:5]
    signature = infer_signature(X_sample, y_sample)
    mlflow.sklearn.log_model(xgb_tuned, "model", signature=signature, input_example=X_sample)

print("Logged XGBoost tuned model to MLflow")
# Out:
# 2025/11/13 19:32:50 INFO mlflow.tracking.fluent: Experiment with name 'model_optimization' does not exist. Creating a new experiment.
# 2025/11/13 19:32:51 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025/11/13 19:33:24 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Logged LightGBM tuned model to MLflow
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Logged XGBoost tuned model to MLflow

# %% [markdown]
# ### Save Models & Artifacts

# %%
os.makedirs('../../models/tuned', exist_ok=True)

joblib.dump(lgb_tuned, '../../models/tuned/lightgbm_tuned_v1.pkl')
joblib.dump(xgb_tuned, '../../models/tuned/xgboost_tuned_v1.pkl')

with open('../../models/tuned/best_params_lgb.json', 'w') as f:
    json.dump(best_params_lgb, f, indent=2)

with open('../../models/tuned/best_params_xgb.json', 'w') as f:
    json.dump(best_params_xgb, f, indent=2)

joblib.dump(study_lgb, '../../models/tuned/optuna_study_lgb.pkl')
joblib.dump(study_xgb, '../../models/tuned/optuna_study_xgb.pkl')

tuning_metadata = {
    'lightgbm': {
        'best_params': best_params_lgb,
        'cv_auc': study_lgb.best_trial.value,
        'val_auc': val_auc_lgb,
        'train_auc': train_auc_lgb,
        'baseline_cv_auc': phase5_metadata['cv_eval']['lgb_cv_mean'],
        'improvement': study_lgb.best_trial.value - phase5_metadata['cv_eval']['lgb_cv_mean'],
        'n_trials': 150
    },
    'xgboost': {
        'best_params': best_params_xgb,
        'cv_auc': study_xgb.best_trial.value,
        'val_auc': val_auc_xgb,
        'train_auc': train_auc_xgb,
        'baseline_cv_auc': phase5_metadata['cv_eval']['xgb_cv_mean'],
        'improvement': study_xgb.best_trial.value - phase5_metadata['cv_eval']['xgb_cv_mean'],
        'n_trials': 150
    }
}

with open('../../models/tuned/tuning_metadata.json', 'w') as f:
    json.dump(tuning_metadata, f, indent=2)

print("Saved artifacts:")
print("  Models: lightgbm_tuned_v1.pkl, xgboost_tuned_v1.pkl")
print("  Best params: best_params_lgb.json, best_params_xgb.json")
print("  Optuna studies: optuna_study_lgb.pkl, optuna_study_xgb.pkl")
print("  Metadata: tuning_metadata.json")
# Out:
# Saved artifacts:
#   Models: lightgbm_tuned_v1.pkl, xgboost_tuned_v1.pkl
#   Best params: best_params_lgb.json, best_params_xgb.json
#   Optuna studies: optuna_study_lgb.pkl, optuna_study_xgb.pkl
#   Metadata: tuning_metadata.json
